# %%
# Read data from file
import numpy as np
def read(filename):
    with open(filename, 'r') as f:
        N, K = map(int, f.readline().split())
        d = [0] + list(map(float, f.readline().split()))
        t = np.zeros((N + 1, N + 1))
        for i in range(N + 1):
            t[i] = list(map(float, f.readline().split()))

    return N, K, d, t

def creat_cost(N, d, t):
    cost_matrix = np.zeros((N + 1, N + 1))
    for i in range(N + 1):
        for j in range(N + 1):
            if i != j:
                cost_matrix[i][j] = d[j] + t[i][j]

    return cost_matrix


file_path = "data\\" + "data_5_2.txt"
N, K, d, t = read(file_path)
cost_matrix = creat_cost(N, d, t)
visited = np.zeros(N + 1)
x = np.zeros(1000, dtype= int)
y = np.zeros(K, dtype = int)
numSegments = 0


def solution():
    for i in range(1, K + 1):
        print(y[i], end = " ")
        temp = x[y[i]]
        while temp != 0:
            print(temp, end = " ")
            temp = x[temp]
        print()

def checkX(v, i, k):
    if v == 0:
        return True
    if visited[v] == 1:
        return False
    return True
    
def checkY(i, k):
    return True

def TryX( i, k, x, y):
    # Dieu kien nhanh can
    for v in range(0, N + 1):
        if checkY(v, i, k):
            x[i] = v
            visited[v] = 1
            numSegments = numSegments + 1
            if v == 0:
                if k == K:
                    if sum(visited[1:N + 1]) == N:
                        solution()
                else:
                    TryX(y[k+1], k + 1, x, y)
            else:
                TryX(v, k, x, y)

            visited[v] = 0
            numSegments = numSegments - 1

def TryY( k, x, y):
        for i in range(y[k-1], N - K + sum(1 for value in y[1: k] if value != 0) + 1):
            if checkY(i, k):
                y[k] = i
                visited[i] = 1
                numSegments = numSegments + 1
                if k == K:
                    TryX(y[1], 1, x, y)
                else:
                    TryY(k + 1, x, y)
                
                visited[i] = 0
                numSegments = numSegments - 1
    
TryY(1, x, y)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[9], line 84
#      81                 visited[i] = 0
#      82                 numSegments = numSegments - 1
# ---> 84 TryY(1, x, y)
#
# Cell In[9], line 75, in TryY(k, x, y)
#      73 y[k] = i
#      74 visited[i] = 1
# ---> 75 numSegments = numSegments + 1
#      76 if k == K:
#      77     TryX(y[1], 1, x, y)
#
# UnboundLocalError: cannot access local variable 'numSegments' where it is not associated with a value
