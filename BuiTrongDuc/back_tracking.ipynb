# %%
# Read data from file
import numpy as np
def read(filename):
    with open(filename, 'r') as f:
        N, K = map(int, f.readline().split())
        d = [0] + list(map(float, f.readline().split()))
        t = np.zeros((N + 1, N + 1))
        for i in range(N + 1):
            t[i] = list(map(float, f.readline().split()))

    return N, K, d, t

def creat_cost(N, d, t):
    cost_matrix = np.zeros((N + 1, N + 1))
    for i in range(N + 1):
        for j in range(N + 1):
            if i != j:
                cost_matrix[i][j] = d[j] + t[i][j]

    return cost_matrix

# %%
class Back_Tracking:
    def __init__(self, file_data):
        self.N, self.K, self.d, self.t = read(file_data)
        self.cost_matrix = creat_cost(self.N, self.d, self.t)
        self.visited = np.zeros(self.N + 1)
        self.x = np.zeros(1000, dtype = int)
        self.y = np.zeros(100, dtype = int)

        self.f_best = 1e9
        self.f_current = 0
        self.numSegments = 0

    def solution(self):
        max_cost = 0
        for k in range(1, self.K + 1):
            temp_cost = 0
            start_employee = self.y[k]
            if start_employee == 0:
                continue
            temp_cost = temp_cost + self.cost_matrix[0][start_employee]
            next_employee = self.x[start_employee]
            while next_employee != 0:
                temp_cost = temp_cost + self.cost_matrix[start_employee][next_employee]
                start_employee = next_employee
                next_employee = self.x[start_employee]
            temp_cost = temp_cost + self.cost_matrix[start_employee][0]
            if temp_cost > max_cost:
                max_cost = temp_cost
        if max_cost < self.f_best:
            self.f_best = max_cost
            self.x_best = self.x.copy()
            self.y_best = self.y.copy()
            

    def checkX(self, v, i, k):
        if v == 0:
            return True
        if self.visited[v] == 1:
             return False
        return True

    def checkY(self, i, k):
        if self.visited[i] == 1:
            return False
        if i == 0:
            if k == self.K:
                return False
        return True
            
        

    def TryX( self, i, k):
        # Dieu kien nhanh can
        for v in range(0, self.N + 1):
            if self.checkX(v, i, k):
                self.x[i] = v
                self.visited[v] = 1
                self.numSegments = self.numSegments + 1
                if v == 0:
                    if k == self.K:
                        if self.numSegments == self.N + self.K:
                            self.solution()
                    else:
                        self.TryX(self.y[k+1], k + 1)
                else:
                    self.TryX(v, k)

                self.visited[v] = 0
                self.numSegments = self.numSegments - 1

    def TryY(self, k):
            for i in range(self.y[k-1] + 1, self.N + 1):
                
                if self.checkY(i, k):
                    self.y[k] = i
                    self.visited[i] = 1
                    self.numSegments = self.numSegments + 1
                    if k == self.K:
                        first = 1
                        while self.y[first] == 0:
                            first = first + 1
                        self.TryX(self.y[first], first)
                    else:
                        self.TryY(k + 1)
                    
                    self.visited[i] = 0
                    self.numSegments = self.numSegments - 1

# %%
import time
def back_tracking(file_data):
    data_path = "data\\" + file_data
    indi = Back_Tracking(data_path)
    start = time.time()
    indi.TryY(1)
    time_run = time.time() - start

    result_data = "Result_Back_tracking\\" + file_data
    with open(result_data, 'w') as f:
        f.write("Objective: " + str(indi.f_best) + "\n")
        f.write("Time run: " + str(time_run) + "\n")
        f.write("Solution: \n")
        for k in range(1, indi.K + 1):
            if indi.y_best[k] == 0:
                f.write("0\n")
            else:
                f.write("0 ")
                temp = indi.y_best[k]
                f.write(str(temp) + " ")
                next_employee = indi.x_best[temp]
                while next_employee != 0:
                    f.write(str(next_employee) + " ")
                    temp = next_employee
                    next_employee = indi.x_best[temp]
                f.write("0\n")

# %%
back_tracking("data_15_7.txt")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 back_tracking("data_15_7.txt")
#
# Cell In[29], line 6, in back_tracking(file_data)
#       4 indi = Back_Tracking(data_path)
#       5 start = time.time()
# ----> 6 indi.TryY(1)
#       7 time_run = time.time() - start
#       9 result_data = "Result_Back_tracking\\" + file_data
#
# Cell In[28], line 84, in Back_Tracking.TryY(self, k)
#      82     self.TryX(self.y[first], first)
#      83 else:
# ---> 84     self.TryY(k + 1)
#      86 self.visited[i] = 0
#      87 self.numSegments = self.numSegments - 1
#
# Cell In[28], line 84, in Back_Tracking.TryY(self, k)
#      82     self.TryX(self.y[first], first)
#      83 else:
# ---> 84     self.TryY(k + 1)
#      86 self.visited[i] = 0
#      87 self.numSegments = self.numSegments - 1
#
#     [... skipping similar frames: Back_Tracking.TryY at line 84 (3 times)]
#
# Cell In[28], line 84, in Back_Tracking.TryY(self, k)
#      82     self.TryX(self.y[first], first)
#      83 else:
# ---> 84     self.TryY(k + 1)
#      86 self.visited[i] = 0
#      87 self.numSegments = self.numSegments - 1
#
# Cell In[28], line 82, in Back_Tracking.TryY(self, k)
#      80     while self.y[first] == 0:
#      81         first = first + 1
# ---> 82     self.TryX(self.y[first], first)
#      83 else:
#      84     self.TryY(k + 1)
#
# Cell In[28], line 66, in Back_Tracking.TryX(self, i, k)
#      64         self.TryX(self.y[k+1], k + 1)
#      65 else:
# ---> 66     self.TryX(v, k)
#      68 self.visited[v] = 0
#      69 self.numSegments = self.numSegments - 1
#
# Cell In[28], line 66, in Back_Tracking.TryX(self, i, k)
#      64         self.TryX(self.y[k+1], k + 1)
#      65 else:
# ---> 66     self.TryX(v, k)
#      68 self.visited[v] = 0
#      69 self.numSegments = self.numSegments - 1
#
#     [... skipping similar frames: Back_Tracking.TryX at line 66 (2 times)]
#
# Cell In[28], line 64, in Back_Tracking.TryX(self, i, k)
#      62             self.solution()
#      63     else:
# ---> 64         self.TryX(self.y[k+1], k + 1)
#      65 else:
#      66     self.TryX(v, k)
#
#     [... skipping similar frames: Back_Tracking.TryX at line 66 (1 times)]
#
# Cell In[28], line 64, in Back_Tracking.TryX(self, i, k)
#      62             self.solution()
#      63     else:
# ---> 64         self.TryX(self.y[k+1], k + 1)
#      65 else:
#      66     self.TryX(v, k)
#
#     [... skipping similar frames: Back_Tracking.TryX at line 66 (2 times), Back_Tracking.TryX at line 64 (2 times)]
#
# Cell In[28], line 66, in Back_Tracking.TryX(self, i, k)
#      64         self.TryX(self.y[k+1], k + 1)
#      65 else:
# ---> 66     self.TryX(v, k)
#      68 self.visited[v] = 0
#      69 self.numSegments = self.numSegments - 1
#
#     [... skipping similar frames: Back_Tracking.TryX at line 64 (1 times)]
#
# Cell In[28], line 64, in Back_Tracking.TryX(self, i, k)
#      62             self.solution()
#      63     else:
# ---> 64         self.TryX(self.y[k+1], k + 1)
#      65 else:
#      66     self.TryX(v, k)
#
# Cell In[28], line 62, in Back_Tracking.TryX(self, i, k)
#      60 if k == self.K:
#      61     if self.numSegments == self.N + self.K:
# ---> 62         self.solution()
#      63 else:
#      64     self.TryX(self.y[k+1], k + 1)
#
# Cell In[28], line 22, in Back_Tracking.solution(self)
#      20 temp_cost = temp_cost + self.cost_matrix[0][start_employee]
#      21 next_employee = self.x[start_employee]
# ---> 22 while next_employee != 0:
#      23     temp_cost = temp_cost + self.cost_matrix[start_employee][next_employee]
#      24     start_employee = next_employee
#
# KeyboardInterrupt:
