# %%
data = ["data_5_2.txt", "data_5_3.txt", "data_10_2.txt", "data_10_3.txt","data_10_5.txt", "data_15_3.txt", "data_15_5.txt", "data_15_7.txt", "data_20_5.txt", "data_20_7.txt","data_20_10.txt", "data_50_5.txt", "data_50_10.txt", "data_50_20.txt", "data_100_10.txt", "data_200_10.txt", "data_200_20.txt", "data_400_40.txt", "data_500_50.txt","data_700_70.txt", "data_900_90.txt", "data_1000_100.txt"]

# %%
for file_data in data:
    print(file_data)
    objective = 0
    time = 0
    for i in range(5):
        if i == 0:
            data_path = "Local_search_greedy1//" + file_data
        else:
            data_path = "Local_search_greedy1//"+ str(i) +"_" + file_data
        
        with open(data_path, "r") as f:
            lines = f.readline().split(" ")
            objective += float(lines[2].strip())
            lines = f.readline().split(" ")
            time += float(lines[2].strip())

    print("objective: ", objective/5)
    print("time: ", time/5)
    print("")
    print("")
# Out:
# data_5_2.txt
# objective:  360.0
# time:  0.11447577476501465
#
#
# data_5_3.txt
# objective:  1029.0
# time:  0.08515548706054688
#
#
# data_10_2.txt
# objective:  578.0
# time:  0.09822053909301758
#
#
# data_10_3.txt
# objective:  1953.6
# time:  0.09594364166259765
#
#
# data_10_5.txt
# objective:  1283.0
# time:  0.10327067375183105
#
#
# data_15_3.txt
# objective:  3753.6
# time:  0.11479682922363281
#
#
# data_15_5.txt
# objective:  1830.0
# time:  0.10803122520446777
#
#
# data_15_7.txt
# objective:  1456.8
# time:  0.11196322441101074
#
#
# data_20_5.txt
# objective:  2322.6
# time:  0.1222463607788086
#
#
# data_20_7.txt
# objective:  1402.2
# time:  0.12046289443969727
#
#
# data_20_10.txt
# objective:  1679.0
# time:  0.12341036796569824
#
#
# data_50_5.txt
# objective:  6484.2
# time:  0.4395806312561035
#
#
# data_50_10.txt
# objective:  2553.6
# time:  0.2442473888397217
#
#
# data_50_20.txt
# objective:  1697.0
# time:  0.1964726448059082
#
#
# data_100_10.txt
# objective:  3718.0
# time:  0.25316405296325684
#
#
# data_200_10.txt
# objective:  4526.0
# time:  0.5114654064178467
#
#
# data_200_20.txt
# objective:  3732.0
# time:  0.5342132568359375
#
#
# data_400_40.txt
# objective:  3702.0
# time:  0.8044517040252686
#
#
# data_500_50.txt
# objective:  3810.0
# time:  0.9502568721771241
#
#
# data_700_70.txt
# objective:  3780.0
# time:  1.2806467056274413
#
#
# data_900_90.txt
# objective:  3720.0
# time:  1.7080374717712403
#
#
# data_1000_100.txt
# objective:  3718.0
# time:  2.279311418533325
